# %% [markdown]
# ## Rake Algorithm
# Rapid Automatic Keyword Extraction algorithm, is a domain independent keyword extraction algorithm which tries to determine key phrases in a body of text by analyzing the frequency of word appearance and its co-occurance with other words in the text.

# %%
from rake_nltk import Rake
import math
import nltk
from nltk.corpus import stopwords
import numpy as np
import mindmap as mm

# %%
from nltk.corpus import stopwords
stop_words = stopwords.words('english')

# %%
r = Rake()

# %%
# Sample Text
myText = '''artificial intelligence (AI), the ability of a digital computer or computer-controlled robot to perform tasks commonly associated with intelligent beings. The term is frequently applied to the project of developing systems endowed with the intellectual processes characteristic of humans, such as the ability to reason, discover meaning, generalize, or learn from past experience. Since the development of the digital computer in the 1940s, it has been demonstrated that computers can be programmed to carry out very complex tasks—as, for example, discovering proofs for mathematical theorems or playing chess—with great proficiency. Still, despite continuing advances in computer processing speed and memory capacity, there are as yet no programs that can match human flexibility over wider domains or in tasks requiring much everyday knowledge. On the other hand, some programs have attained the performance levels of human experts and professionals in performing certain specific tasks, so that artificial intelligence in this limited sense is found in applications as diverse as medical diagnosis, computer search engines, and voice or handwriting recognition. All but the simplest human behaviour is ascribed to intelligence, while even the most complicated insect behaviour is never taken as an indication of intelligence. What is the difference? Consider the behaviour of the digger wasp, Sphex ichneumoneus. When the female wasp returns to her burrow with food, she first deposits it on the threshold, checks for intruders inside her burrow, and only then, if the coast is clear, carries her food inside. The real nature of the wasp’s instinctual behaviour is revealed if the food is moved a few inches away from the entrance to her burrow while she is inside: on emerging, she will repeat the whole procedure as often as the food is displaced. Intelligence—conspicuously absent in the case of Sphex—must include the ability to adapt to new circumstances. Psychologists generally do not characterize human intelligence by just one trait but by the combination of many diverse abilities. Research in AI has focused chiefly on the following components of intelligence: learning, reasoning, problem solving, perception, and using language. There are a number of different forms of learning as applied to artificial intelligence. An example of the former is, “Fred must be in either the museum or the café. He is not in the café; therefore he is in the museum, and of the latter, Previous accidents of this sort were caused by instrument failure; therefore this accident was caused by instrument failure. The most significant difference between these forms of reasoning is that in the deductive case the truth of the premises guarantees the truth of the conclusion, whereas in the inductive case the truth of the premise lends support to the conclusion without giving absolute assurance. Inductive reasoning is common in science, where data are collected and tentative models are developed to describe and predict future behaviour—until the appearance of anomalous data forces the model to be revised. Deductive reasoning is common in mathematics and logic, where elaborate structures of irrefutable theorems are built up from a small set of basic axioms and rules. There has been considerable success in programming computers to draw inferences, especially deductive inferences. However, true reasoning involves more than just drawing inferences; it involves drawing inferences relevant to the solution of the particular task or situation. This is one of the hardest problems confronting AI. Artificial intelligence systems are critical for companies that wish to extract value from data by automating and optimizing processes or producing actionable insights. Artificial intelligence systems powered by machine learning enable companies to leverage large amounts of available data to uncover insights and patterns that would be impossible for any one person to identify, enabling them to deliver more targeted, personalized communications, predict critical care events, identify likely fraudulent transactions, and more. DataRobot was founded on the belief that emerging AI and machine learning technologies should be available to all enterprises, regardless of size and resources. That’s why we invented automated machine learning, which allows users of all skill levels to easily and rapidly build and deploy machine learning models.
DataRobot believes in the democratization of AI, and for that reason, we developed a platform to enable business users across organizations to gain actionable, practical insights that result in tangible business value. DataRobot makes the power of AI accessible to users throughout your business, helping your organization transform into an AI-driven enterprise.'''

# %%
r.extract_keywords_from_text(myText)

# %%
r.get_ranked_phrases_with_scores()
# Out:
# [(24.0, 'tasks requiring much everyday knowledge'),
#  (23.0, 'conclusion without giving absolute assurance'),
#  (20.5, 'enable business users across organizations'),
#  (16.0, 'performing certain specific tasks'),
#  (16.0, 'perform tasks commonly associated'),
#  (14.583333333333334, 'invented automated machine learning'),
#  (14.5, 'predict critical care events'),
#  (14.5, 'identify likely fraudulent transactions'),
#  (14.2, 'predict future behaviour —'),
#  (14.1, 'sphex — must include'),
#  (13.9, 'intelligence — conspicuously absent'),
#  (13.857142857142858, 'hardest problems confronting ai'),
#  (13.583333333333334, 'machine learning enable companies'),
#  (13.583333333333334, 'deploy machine learning models'),
#  (13.25, 'involves drawing inferences relevant'),
#  (12.233333333333334, 'artificial intelligence systems powered'),
#  (10.6, 'complex tasks —'),
#  (9.6, 'playing chess —'),
#  (9.583333333333334, 'machine learning technologies'),
#  (9.5, '“ fred must'),
#  (9.333333333333334, 'developing systems endowed'),
#  (9.0, 'premise lends support'),
#  (9.0, 'leverage large amounts'),
#  (9.0, 'despite continuing advances'),
#  (8.75, 'match human flexibility'),
#  (8.6, 'complicated insect behaviour'),
#  (8.5, 'tangible business value'),
#  (8.5, 'intellectual processes characteristic'),
#  (8.35, 'simplest human behaviour'),
#  (8.333333333333334, 'female wasp returns'),
#  (8.3, 'true reasoning involves'),
#  (8.233333333333334, 'artificial intelligence systems'),
#  (8.2, 'computer search engines'),
#  (8.2, 'computer processing speed'),
#  (8.083333333333334, 'especially deductive inferences'),
#  (8.05, 'characterize human intelligence'),
#  (8.0, 'many diverse abilities'),
#  (7.833333333333334, 'producing actionable insights'),
#  (7.75, 'anomalous data forces'),
#  (5.75, 'drawing inferences'),
#  (5.0, 'users throughout'),
#  (5.0, 'tentative models'),
#  (5.0, 'sphex ichneumoneus'),
#  (5.0, 'allows users'),
#  (4.9, 'artificial intelligence'),
#  (4.9, 'artificial intelligence'),
#  (4.9, 'artificial intelligence'),
#  (4.75, 'human experts'),
#  (4.75, 'draw inferences'),
#  (4.6, 'instinctual behaviour'),
#  (4.5, 'optimizing processes'),
#  (4.5, 'gain actionable'),
#  (4.5, 'extract value'),
#  (4.333333333333334, 'uncover insights'),
#  (4.333333333333334, 'practical insights'),
#  (4.333333333333334, 'digger wasp'),
#  (4.2, 'digital computer'),
#  (4.2, 'digital computer'),
#  (4.133333333333334, 'deductive reasoning'),
#  (4.0, 'wider domains'),
#  (4.0, 'whole procedure'),
#  (4.0, 'using language'),
#  (4.0, 'small set'),
#  (4.0, 'skill levels'),
#  (4.0, 'real nature'),
#  (4.0, 'rapidly build'),
#  (4.0, 'psychologists generally'),
#  (4.0, 'problem solving'),
#  (4.0, 'previous accidents'),
#  (4.0, 'premises guarantees'),
#  (4.0, 'personalized communications'),
#  (4.0, 'performance levels'),
#  (4.0, 'past experience'),
#  (4.0, 'particular task'),
#  (4.0, 'organization transform'),
#  (4.0, 'new circumstances'),
#  (4.0, 'never taken'),
#  (4.0, 'memory capacity'),
#  (4.0, 'medical diagnosis'),
#  (4.0, 'mathematical theorems'),
#  (4.0, 'limited sense'),
#  (4.0, 'irrefutable theorems'),
#  (4.0, 'intelligent beings'),
#  (4.0, 'instrument failure'),
#  (4.0, 'instrument failure'),
#  (4.0, 'inches away'),
#  (4.0, 'handwriting recognition'),
#  (4.0, 'great proficiency'),
#  (4.0, 'following components'),
#  (4.0, 'focused chiefly'),
#  (4.0, 'first deposits'),
#  (4.0, 'elaborate structures'),
#  (4.0, 'driven enterprise'),
#  (4.0, 'discovering proofs'),
#  (4.0, 'discover meaning'),
#  (4.0, 'deductive case'),
#  (4.0, 'controlled robot'),
#  (4.0, 'considerable success'),
#  (4.0, 'basic axioms'),
#  (3.857142857142857, 'ai accessible'),
#  (3.857142857142857, 'ai ),'),
#  (3.8333333333333335, 'wasp ’'),
#  (3.8, 'inductive reasoning'),
#  (3.666666666666667, 'one trait'),
#  (3.666666666666667, 'one person'),
#  (3.666666666666667, 'intruders inside'),
#  (3.666666666666667, 'inductive case'),
#  (3.666666666666667, 'datarobot makes'),
#  (3.666666666666667, 'datarobot believes'),
#  (3.5, 'significant difference'),
#  (3.5, 'programming computers'),
#  (3.5, 'frequently applied'),
#  (3.5, 'different forms'),
#  (3.357142857142857, 'emerging ai'),
#  (3.25, 'available data'),
#  (3.0, 'conclusion'),
#  (3.0, 'business'),
#  (2.916666666666667, 'food inside'),
#  (2.8333333333333335, 'learning'),
#  (2.8333333333333335, 'learning'),
#  (2.6, 'behaviour'),
#  (2.5, 'identify'),
#  (2.5, 'critical'),
#  (2.5, 'companies'),
#  (2.3, 'intelligence'),
#  (2.3, 'intelligence'),
#  (2.3, 'intelligence'),
#  (2.2, 'computer'),
#  (2.0, 'diverse'),
#  (1.8571428571428572, 'ai'),
#  (1.8571428571428572, 'ai'),
#  (1.8571428571428572, 'ai'),
#  (1.8, 'reasoning'),
#  (1.8, 'reasoning'),
#  (1.75, 'data'),
#  (1.75, 'data'),
#  (1.6666666666666667, 'one'),
#  (1.6666666666666667, 'inside'),
#  (1.6666666666666667, 'datarobot'),
#  (1.6666666666666667, 'case'),
#  (1.5, '’'),
#  (1.5, 'forms'),
#  (1.5, 'emerging'),
#  (1.5, 'difference'),
#  (1.5, 'computers'),
#  (1.5, 'available'),
#  (1.5, 'applied'),
#  (1.25, 'food'),
#  (1.25, 'food'),
#  (1.25, 'food'),
#  (1.0, 'yet'),
#  (1.0, 'would'),
#  (1.0, 'wish'),
#  (1.0, 'whereas'),
#  (1.0, 'voice'),
#  (1.0, 'truth'),
#  (1.0, 'truth'),
#  (1.0, 'truth'),
#  (1.0, 'threshold'),
#  (1.0, 'therefore'),
#  (1.0, 'therefore'),
#  (1.0, 'term'),
#  (1.0, 'targeted'),
#  (1.0, 'still'),
#  (1.0, 'sort'),
#  (1.0, 'solution'),
#  (1.0, 'size'),
#  (1.0, 'situation'),
#  (1.0, 'since'),
#  (1.0, 'science'),
#  (1.0, 'rules'),
#  (1.0, 'revised'),
#  (1.0, 'revealed'),
#  (1.0, 'result'),
#  (1.0, 'resources'),
#  (1.0, 'research'),
#  (1.0, 'repeat'),
#  (1.0, 'regardless'),
#  (1.0, 'reason'),
#  (1.0, 'reason'),
#  (1.0, 'project'),
#  (1.0, 'programs'),
#  (1.0, 'programs'),
#  (1.0, 'programmed'),
#  (1.0, 'professionals'),
#  (1.0, 'power'),
#  (1.0, 'platform'),
#  (1.0, 'perception'),
#  (1.0, 'patterns'),
#  (1.0, 'often'),
#  (1.0, 'number'),
#  (1.0, 'museum'),
#  (1.0, 'museum'),
#  (1.0, 'moved'),
#  (1.0, 'model'),
#  (1.0, 'mathematics'),
#  (1.0, 'logic'),
#  (1.0, 'learn'),
#  (1.0, 'latter'),
#  (1.0, 'indication'),
#  (1.0, 'impossible'),
#  (1.0, 'humans'),
#  (1.0, 'however'),
#  (1.0, 'helping'),
#  (1.0, 'hand'),
#  (1.0, 'generalize'),
#  (1.0, 'founded'),
#  (1.0, 'found'),
#  (1.0, 'former'),
#  (1.0, 'example'),
#  (1.0, 'example'),
#  (1.0, 'even'),
#  (1.0, 'entrance'),
#  (1.0, 'enterprises'),
#  (1.0, 'enabling'),
#  (1.0, 'either'),
#  (1.0, 'easily'),
#  (1.0, 'displaced'),
#  (1.0, 'development'),
#  (1.0, 'developed'),
#  (1.0, 'developed'),
#  (1.0, 'describe'),
#  (1.0, 'demonstrated'),
#  (1.0, 'democratization'),
#  (1.0, 'deliver'),
#  (1.0, 'consider'),
#  (1.0, 'common'),
#  (1.0, 'common'),
#  (1.0, 'combination'),
#  (1.0, 'collected'),
#  (1.0, 'coast'),
#  (1.0, 'clear'),
#  (1.0, 'checks'),
#  (1.0, 'caused'),
#  (1.0, 'caused'),
#  (1.0, 'carry'),
#  (1.0, 'carries'),
#  (1.0, 'café'),
#  (1.0, 'café'),
#  (1.0, 'burrow'),
#  (1.0, 'burrow'),
#  (1.0, 'burrow'),
#  (1.0, 'built'),
#  (1.0, 'belief'),
#  (1.0, 'automating'),
#  (1.0, 'attained'),
#  (1.0, 'ascribed'),
#  (1.0, 'applications'),
#  (1.0, 'appearance'),
#  (1.0, 'adapt'),
#  (1.0, 'accident'),
#  (1.0, 'ability'),
#  (1.0, 'ability'),
#  (1.0, 'ability'),
#  (1.0, '1940s')]

# %% [markdown]
# Now, As we need to make a mindmap out of it we will be passing it through the LDA topic modelling Algo first and the clusters that are formed will be then passed through this to get the required keywords.

# %%
#Output from the LDA model

grouped_text = {0: 'He is not in the cafÃ©; therefore he is in the museum, and of the latter, Previous accidents of this sort were caused by instrument failure; therefore this accident was caused by instrument failure.The most significant difference between these forms of reasoning is that in the deductive case the truth of the premises guarantees the truth of the conclusion, whereas in the inductive case the truth of the premise lends support to the conclusion without giving absolute assurance.Inductive reasoning is common in science, where data are collected and tentative models are developed to describe and predict future behaviourâ€”until the appearance of anomalous data forces the model to be revised.',
 1: 'Deductive reasoning is common in mathematics and logic, where elaborate structures of irrefutable theorems are built up from a small set of basic axioms and rules.There has been considerable success in programming computers to draw inferences, especially deductive inferences.However, true reasoning involves more than just drawing inferences; it involves drawing inferences relevant to the solution of the particular task or situation.',
 2: '',
 3: 'artificial intelligence (AI), the ability of a digital computer or computer-controlled robot to perform tasks commonly associated with intelligent beings.The term is frequently applied to the project of developing systems endowed with the intellectual processes characteristic of humans, such as the ability to reason, discover meaning, generalize, or learn from past experience.Since the development of the digital computer in the 1940s, it has been demonstrated that computers can be programmed to carry out very complex tasksâ€”as, for example, discovering proofs for mathematical theorems or playing chessâ€”with great proficiency.Research in AI has focused chiefly on the following components of intelligence: learning, reasoning, problem solving, perception, and using language.There are a number of different forms of learning as applied to artificial intelligence.An example of the former is, â€œFred must be in either the museum or the cafÃ©.',
 4: '',
 5: 'The real nature of the waspâ€™s instinctual behaviour is revealed if the food is moved a few inches away from the entrance to her burrow while she is inside: on emerging, she will repeat the whole procedure as often as the food is displaced.Intelligenceâ€”conspicuously absent in the case of Sphexâ€”must include the ability to adapt to new circumstances.Psychologists generally do not characterize human intelligence by just one trait but by the combination of many diverse abilities.This is one of the hardest problems confronting AI.Artificial intelligence systems are critical for companies that wish to extract value from data by automating and optimizing processes or producing actionable insights.Artificial intelligence systems powered by machine learning enable companies to leverage large amounts of available data to uncover insights and patterns that would be impossible for any one person to identify, enabling them to deliver more targeted, personalized communications, predict critical care events, identify likely fraudulent transactions, and more.',
 6: '',
 7: 'What is the difference?Consider the behaviour of the digger wasp, Sphex ichneumoneus.When the female wasp returns to her burrow with food, she first deposits it on the threshold, checks for intruders inside her burrow, and only then, if the coast is clear, carries her food inside.',
 8: 'Still, despite continuing advances in computer processing speed and memory capacity, there are as yet no programs that can match human flexibility over wider domains or in tasks requiring much everyday knowledge.On the other hand, some programs have attained the performance levels of human experts and professionals in performing certain specific tasks, so that artificial intelligence in this limited sense is found in applications as diverse as medical diagnosis, computer search engines, and voice or handwriting recognition.All but the simplest human behaviour is ascribed to intelligence, while even the most complicated insect behaviour is never taken as an indication of intelligence.',
 9: 'DataRobot was founded on the belief that emerging AI and machine learning technologies should be available to all enterprises, regardless of size and resources.Thatâ€™s why we invented automated machine learning, which allows users of all skill levels to easily and rapidly build and deploy machine learning models.'}

# %%
#OLD Method - Not efficient

def set_threshold(phrases):
    total_score = 0
    max_score = 0
    min_score = math.inf
    for phrase in phrases:
        score = phrase[0]
        if (score > max_score):
            max_score = score
        if(score < min_score):
            min_score = score
        total_score += score
    mean_score = total_score / len(phrase)
    print(total_score, max_score, min_score, mean_score)
    return (total_score /  abs(max_score - mean_score))

# %%
def set_threshold_quartile(phrases):
    scores = []
    for phrase in phrases:
        scores.append(phrase[0])
    threshold = np.percentile(scores, 75)
    return threshold

# %%
def set_threshold_variance(phrases):
    scores = []
    for phrase in phrases:
        scores.append(phrase[0])
    std_dev = np.var(scores) ** 0.5
    total = sum(scores)
    mean_scores = total / len(scores)
    threshold = mean_scores + std_dev * 2
    print(threshold)
    return threshold

# %%
def get_best_phrases(phrases, threshold=4):
    final_phrases = []
    for phrase in phrases:
        if(phrase[0] > math.floor(threshold)):
            final_phrases.append(phrase[1])

    return final_phrases

# %%
def get_best_phrases(phrases, threshold=4):
    final_phrases = []
    for phrase in phrases:
        if(phrase[0] > math.floor(threshold)):
            if(final_phrases):
                flag = 0
                for prev_phrase in final_phrases:
                    similarity = mm.sentence_similarity(prev_phrase, phrase[1], stop_words)
                    if(similarity > 0.96):
                        flag = 1
                        break
                if(not flag):
                    final_phrases.append(phrase[1])
            else:
                final_phrases.append(phrase[1])

    return final_phrases

# %%
def get_keywords(grouped_text):
    final_keywords = []
    stop_words = stopwords.words('english')
    for idx in grouped_text:
        if(grouped_text[idx]):
            rake_model = Rake()
            rake_model.extract_keywords_from_text(grouped_text[idx])
            phrases = rake_model.get_ranked_phrases_with_scores()
            threshold = set_threshold_quartile(phrases)
            best_phrases = get_best_phrases(phrases, threshold)
            final_keywords.append(best_phrases)
        else:
            final_keywords.append([])
    return final_keywords

# %%
get_keywords(grouped_text)
# Out:
# [['conclusion without giving absolute assurance',
#   'predict future behaviourâ €”',
#   'premise lends support',
#   'cafã ©; therefore',
#   'anomalous data forces'],
#  ['involves drawing inferences relevant',
#   'true reasoning involves',
#   'especially deductive inferences',
#   'drawing inferences',
#   'deductive reasoning'],
#  [],
#  ['â € œfred must',
#   'perform tasks commonly associated',
#   'playing chessâ €”',
#   'intellectual processes characteristic',
#   'developing systems endowed',
#   'complex tasksâ €”'],
#  [],
#  ['sphexâ €” must include',
#   'intelligenceâ €” conspicuously absent',
#   'hardest problems confronting ai',
#   'predict critical care events',
#   'machine learning enable companies',
#   'identify likely fraudulent transactions',
#   'artificial intelligence systems powered',
#   'characterize human intelligence',
#   'many diverse abilities',
#   'leverage large amounts',
#   'producing actionable insights',
#   'uncover insights'],
#  [],
#  ['female wasp returns', 'digger wasp'],
#  ['tasks requiring much everyday knowledge',
#   'performing certain specific tasks',
#   'despite continuing advances',
#   'computer search engines',
#   'computer processing speed',
#   'complicated insect behaviour',
#   'simplest human behaviour',
#   'match human flexibility',
#   'human experts'],
#  ['invented automated machine learning',
#   'deploy machine learning models',
#   'machine learning technologies']]

# %% [markdown]
# ## Finding common phrases

# %%
def get_common_phrases(phrase_list):
    common_phrases = []
    for group1 in phrase_list:
        for phrase1 in group1:
            for group2 in phrase_list:
                if(group1 != group2):
                    for phrase2 in group2:
                            if(phrase1[1] == phrase2[1]):
                                common_phrases.append([phrase1[1], output.index(group1), output.index(group2)])
    return common_phrases

# %%
def get_common_phrases(phrase_list, max_nodes=4):
    common_phrases = []
    for group1 in phrase_list:
        flag = 0
        count_common_phrases = 0
        for phrase1 in group1:
            for group2 in phrase_list:
                if(group1 != group2):
                    for phrase2 in group2:
                        if(phrase1[1] == phrase2[1]):
                            common_phrases.append([phrase1[1], phrase_list.index(group1), phrase_list.index(group2)])
                            count_common_phrases += 1
                            if(count_common_phrases == max_nodes):
                                flag = 1
                                break
                    if(flag):
                        break
            if(flag):
                break
                       
    return common_phrases

# %%
def get_keywords_v2(grouped_text):
    phrases_list = []
    stop_words = stopwords.words('english')
    for idx in grouped_text:
        if(grouped_text[idx]):
            rake_model = Rake()
            rake_model.extract_keywords_from_text(grouped_text[idx])
            phrases = rake_model.get_ranked_phrases_with_scores()
            phrases_list.append(phrases)
        else:
            phrases_list.append([])
    final_keywords = get_best_phrases_v2(phrases_list)
    common_list = get_common_phrases(phrases_list)
    print(common_list)
    for phrase in common_list:
        keyword = phrase[0]
        if(keyword not in final_keywords[phrase[1]]):
            final_keywords[phrase[1]].append(keyword)
        if(keyword not in final_keywords[phrase[2]]):
            final_keywords[phrase[2]].append(keyword)
    return final_keywords

# %%
def get_best_phrases_v2(phrase_list):
    final_phrases = []
    for phrases in phrase_list:
        final_phrases_topic = []
        if(phrases):
            threshold = set_threshold_quartile(phrases)
            for phrase in phrases:
                if(phrase[0] > math.floor(threshold)):
                    if(final_phrases_topic):
                        flag = 0
                        for prev_phrase in final_phrases:
                            if(prev_phrase):
                                similarity = mm.sentence_similarity(prev_phrase, phrase[1], stop_words)
                                if(similarity > 0.96):
                                    flag = 1
                                    break
                        if(not flag):
                            final_phrases_topic.append(phrase[1])
                    else:
                        final_phrases_topic.append(phrase[1])
        final_phrases.append(final_phrases_topic)
    return final_phrases

# %%
import warnings

# %%
warnings.filterwarnings('default')
# default error

# %%
phrase_list = get_keywords_v2(grouped_text)

# %%
import ldamodule

# %%
with open('./sample_text2.txt', encoding="utf8") as f:
    input_text = f.readlines()
final_text = ''
for text in input_text:
    final_text += text

# %%
grouped_text, topics = ldamodule.create_topics(final_text, 3, 10)

# %%
phrase_list = get_keywords_v2(grouped_text)
# Out:
# [['conservation efforts', 0, 5], ['conservation efforts', 0, 5], ['conservation efforts', 0, 5], ['welfare', 0, 5], ['technology', 1, 3], ['supporting', 1, 0], ['size', 1, 8], ['matches', 1, 9], ['zoos', 2, 0], ['zoos', 2, 0], ['zoos', 2, 0], ['zoos', 2, 5], ['consumers', 3, 6], ['consumers', 3, 9], ['usability', 3, 9], ['technology', 3, 1], ['conservation efforts', 5, 0], ['conservation efforts', 5, 0], ['conservation efforts', 5, 0], ['conservation', 5, 0], ['“', 6, 8], ['convenience', 6, 9], ['consumers', 6, 3], ['consumers', 6, 9], ['“', 8, 6], ['wildlife', 8, 5], ['size', 8, 1], ['need', 8, 0], ['usability', 9, 3], ['model', 9, 0], ['matches', 9, 1], ['convenience', 9, 6]]

# %%
count = 0
for phrase in phrase_list:
    count += len(phrase)
    print(phrase)
# Out:
# ['date examines zoo visitors ’ behaviors', 'rose et al ., 2009', 'also impair zoo animals ’ welfare', 'many zoos contribute little', 'research review examines', 'high attendance levels', 'fast wireless charging', 'energy storage capacity', 'art battery scale', 'animal rights activists', 'repurposing car batteries', 'electric automotive future', 'using wmg ’', 'project explores ways', 'forthcoming ukbic facility', 'project allows wmg', 'zoos ’ education', 'gives accredited zoos', 'zoo programming', 'institutions also', 'wmg ’', '’ connor', 'nextrode project', 'accredited zoos', 'using ultra', 'optimise ways', 'near future', 'ion batteries', 'zoos influence', 'conservation efforts', 'welfare', 'supporting', 'zoos', 'conservation', 'need', 'model']
# ['zero ’ strategy — aiming', 'includes project partner a123 systems', 'funded multi optimal solutions', '£ 2m innovate uk', 'therefore pressing questions around', 'meeting consumers ’ expectations', 'make road transport emission', 'buy electric cars today', 'energy storage systems', 'widespread scepticism around', 'optimistic world come', 'uk government ’', 'electric transport', 'electric cars', 'government ’', '‘ road', 'nation ’', 'electric vehicle', 'technology', 'supporting', 'size', 'matches']
# ['2011 ). approximately 700 million people visit zoos', 'moss et al ., 2014 ),', 'currently affordable traction batteries need', '700 conservation programs spent approximately', '2011 survey indicating', 'wildlife conservation internationally', '650 individual species', '2011 ).', 'aquariums worldwide annually', '350 million', '2012 ).', '160 million', 'aquariums spent', 'field conservation', 'zoos']
# ['consumers ’ typical mobility behaviours', 'short journeys somewhat counteracts', 'robust battery charging infrastructure', 'deliver 300 miles', 'charging infrastructure', 'battery sized', '50 miles', 'technology', 'consumers', 'usability']
# []
# ['fernandez et al ., 2009', 'particular captive environments help', 'future zoo visitor research', 'causal factors related', 'research also suggests', 'current research suggests', 'specific effects visiting', 'promotes aza ’', 'site conservation opportunities', 'visitors tell us', 'conservation efforts compared', 'research exists', 'academic research', 'aza ),', 'conservation efforts', 'conservation efforts', 'conservation efforts', 'zoo visitors', 'habitat conservation', 'conservation messaging', 'welfare', 'zoos', 'conservation', 'wildlife']
# ['high power density cells ,” says greenwood .“', 'existing solutions .” although efficiency', 'cost also remains front', 'reduced dedicated crash structure', 'highly energy dense solid', 'reduced charging time', 'better energy storage', 'consumers', '“', 'convenience']
# []
# ['would deliver around 150 miles', 'passenger car batteries could shrink', 'wild counterparts ’ conservation needs', 'ubiquitous fast charging network', 'key ,” explains greenwood', 'desired electric range capability', 'class energy densities mean', 'efficient battery charging infrastructure', 'long charging times', 'real world range', 'professor greenwood added', 'large ev batteries', 'size', '“', 'wildlife', 'need']
# ['conventional vehicles offer today according', 'professor david greenwood', 'next decade presents', 'electrification industry estimated', '£ 6bn', 'offered something', 'massive opportunity', 'cars increased', 'matches', 'consumers', 'usability', 'convenience', 'model']

# %%
count
# Out:
# 146

# %%
phrase_list
# Out:
# [['date examines zoo visitors ’ behaviors',
#   'rose et al ., 2009',
#   'also impair zoo animals ’ welfare',
#   'many zoos contribute little',
#   'research review examines',
#   'high attendance levels',
#   'fast wireless charging',
#   'energy storage capacity',
#   'art battery scale',
#   'animal rights activists',
#   'repurposing car batteries',
#   'electric automotive future',
#   'using wmg ’',
#   'project explores ways',
#   'forthcoming ukbic facility',
#   'project allows wmg',
#   'zoos ’ education',
#   'gives accredited zoos',
#   'zoo programming',
#   'institutions also',
#   'wmg ’',
#   '’ connor',
#   'nextrode project',
#   'accredited zoos',
#   'using ultra',
#   'optimise ways',
#   'near future',
#   'ion batteries',
#   'zoos influence',
#   'conservation efforts',
#   'welfare',
#   'supporting',
#   'zoos',
#   'conservation',
#   'need',
#   'model'],
#  ['zero ’ strategy — aiming',
#   'includes project partner a123 systems',
#   'funded multi optimal solutions',
#   '£ 2m innovate uk',
#   'therefore pressing questions around',
#   'meeting consumers ’ expectations',
#   'make road transport emission',
#   'buy electric cars today',
#   'energy storage systems',
#   'widespread scepticism around',
#   'optimistic world come',
#   'uk government ’',
#   'electric transport',
#   'electric cars',
#   'government ’',
#   '‘ road',
#   'nation ’',
#   'electric vehicle',
#   'technology',
#   'supporting',
#   'size',
#   'matches'],
#  ['2011 ). approximately 700 million people visit zoos',
#   'moss et al ., 2014 ),',
#   'currently affordable traction batteries need',
#   '700 conservation programs spent approximately',
#   '2011 survey indicating',
#   'wildlife conservation internationally',
#   '650 individual species',
#   '2011 ).',
#   'aquariums worldwide annually',
#   '350 million',
#   '2012 ).',
#   '160 million',
#   'aquariums spent',
#   'field conservation',
#   'zoos'],
#  ['consumers ’ typical mobility behaviours',
#   'short journeys somewhat counteracts',
#   'robust battery charging infrastructure',
#   'deliver 300 miles',
#   'charging infrastructure',
#   'battery sized',
#   '50 miles',
#   'technology',
#   'consumers',
#   'usability'],
#  [],
#  ['fernandez et al ., 2009',
#   'particular captive environments help',
#   'future zoo visitor research',
#   'causal factors related',
#   'research also suggests',
#   'current research suggests',
#   'specific effects visiting',
#   'promotes aza ’',
#   'site conservation opportunities',
#   'visitors tell us',
#   'conservation efforts compared',
#   'research exists',
#   'academic research',
#   'aza ),',
#   'conservation efforts',
#   'conservation efforts',
#   'conservation efforts',
#   'zoo visitors',
#   'habitat conservation',
#   'conservation messaging',
#   'welfare',
#   'zoos',
#   'conservation',
#   'wildlife'],
#  ['high power density cells ,” says greenwood .“',
#   'existing solutions .” although efficiency',
#   'cost also remains front',
#   'reduced dedicated crash structure',
#   'highly energy dense solid',
#   'reduced charging time',
#   'better energy storage',
#   'consumers',
#   '“',
#   'convenience'],
#  [],
#  ['would deliver around 150 miles',
#   'passenger car batteries could shrink',
#   'wild counterparts ’ conservation needs',
#   'ubiquitous fast charging network',
#   'key ,” explains greenwood',
#   'desired electric range capability',
#   'class energy densities mean',
#   'efficient battery charging infrastructure',
#   'long charging times',
#   'real world range',
#   'professor greenwood added',
#   'large ev batteries',
#   'size',
#   '“',
#   'wildlife',
#   'need'],
#  ['conventional vehicles offer today according',
#   'professor david greenwood',
#   'next decade presents',
#   'electrification industry estimated',
#   '£ 6bn',
#   'offered something',
#   'massive opportunity',
#   'cars increased',
#   'matches',
#   'consumers',
#   'usability',
#   'convenience',
#   'model']]
